# %%
from real_estate.scrape import domain_rental_listings
import time

# %%
BASE_URL = "https://www.domain.com.au/rent/adelaide-region-sa/?page="

all_listings = []

for i in range(100):
    url = f"{BASE_URL}{i + 1}"
    page_listings = domain_listings(url, HEADERS)
    all_listings.extend(page_listings)
    time.sleep(10)
    break

# %%
all_listings
# Out:
# [{'id': 'listing-16676796',
#   'datetime': datetime.datetime(2023, 9, 28, 0, 0),
#   'price': 1200,
#   'street_address': '30 mary penfold drive',
#   'suburb': 'rosslyn park',
#   'state': 'sa',
#   'postcode': '5072',
#   'beds': 4,
#   'baths': 3,
#   'parking': 2,
#   'type': 'house'},
#  {'id': 'listing-16676577',
#   'datetime': datetime.datetime(2023, 9, 28, 0, 0),
#   'price': 485,
#   'street_address': '317 fradd east road',
#   'suburb': 'munno para west',
#   'state': 'sa',
#   'postcode': '5115',
#   'beds': 3,
#   'baths': 2,
#   'parking': 4,
#   'type': 'house'},
#  {'id': 'listing-16676188',
#   'datetime': datetime.datetime(2023, 9, 28, 0, 0),
#   'price': 650,
#   'street_address': '48 rapid avenue',
#   'suburb': 'lightsview',
#   'state': 'sa',
#   'postcode': '5085',
#   'beds': 3,
#   'baths': 2,
#   'parking': 2,
#   'type': 'townhouse'},
#  {'id': 'listing-16676029',
#   'datetime': datetime.datetime(2023, 9, 28, 0, 0),
#   'price': 750,
# ...
